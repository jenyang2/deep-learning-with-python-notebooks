# %%
import keras
keras.__version__
# Out:
# Using TensorFlow backend.
# '2.2.0'

# %% [markdown]
# # Text generation with LSTM
#
# This notebook contains the code samples found in Chapter 8, Section 1 of [Deep Learning with Python](https://www.manning.com/books/deep-learning-with-python?a_aid=keras&a_bid=76564dff). Note that the original text features far more content, in particular further explanations and figures: in this notebook, you will only find source code and related comments.
#
# ----
#
# [...]
#
# ## Implementing character-level LSTM text generation
#
#
# Let's put these ideas in practice in a Keras implementation. The first thing we need is a lot of text data that we can use to learn a
# language model. You could use any sufficiently large text file or set of text files -- Wikipedia, the Lord of the Rings, etc. In this
# example we will use some of the writings of Nietzsche, the late-19th century German philosopher (translated to English). The language model
# we will learn will thus be specifically a model of Nietzsche's writing style and topics of choice, rather than a more generic model of the
# English language.

# %% [markdown]
# ## Preparing the data
#
# Let's start by downloading the corpus and converting it to lowercase:

# %%
import keras
import numpy as np

path = keras.utils.get_file(
    'nietzsche.txt',
    origin='https://s3.amazonaws.com/text-datasets/nietzsche.txt')
text = open(path).read().lower()
print('말뭉치 크기:', len(text))
# Out:
# Corpus length: 600893

# %%
type(text)
# Out:
# str

# %% [markdown]
# Next, we will extract partially-overlapping sequences of length `maxlen`, one-hot encode them and pack them in a 3D Numpy array `x` of
# shape `(sequences, maxlen, unique_characters)`. Simultaneously, we prepare a array `y` containing the corresponding targets: the one-hot
# encoded characters that come right after each extracted sequence.

# %%
# Length of extracted character sequences
maxlen = 60

# We sample a new sequence every `step` characters
step = 3

# This holds our extracted sequences
sentences = []

# This holds the targets (the follow-up characters)
next_chars = []

for i in range(0, len(text) - maxlen, step):
    sentences.append(text[i: i + maxlen])
    next_chars.append(text[i + maxlen])
print('시퀀스 개수:', len(sentences))

# List of unique characters in the corpus
chars = sorted(list(set(text)))
print('고유한 글자:', len(chars))
# Dictionary mapping unique characters to their index in `chars`
char_indices = dict((char, chars.index(char)) for char in chars)

# Next, one-hot encode the characters into binary arrays.
print('벡터화...')
x = np.zeros((len(sentences), maxlen, len(chars)), dtype=np.bool)
y = np.zeros((len(sentences), len(chars)), dtype=np.bool)
for i, sentence in enumerate(sentences):
    for t, char in enumerate(sentence):
        x[i, t, char_indices[char]] = 1
    y[i, char_indices[next_chars[i]]] = 1
# Out:
# Number of sequences: 200278
# Unique characters: 57
# Vectorization...

# %% [markdown]
# ## Building the network
#
# Our network is a single `LSTM` layer followed by a `Dense` classifier and softmax over all possible characters. But let us note that
# recurrent neural networks are not the only way to do sequence data generation; 1D convnets also have proven extremely successful at it in
# recent times.

# %%
from keras import layers

model = keras.models.Sequential()
model.add(layers.LSTM(128, input_shape=(maxlen, len(chars))))
model.add(layers.Dense(len(chars), activation='softmax'))

# %% [markdown]
# Since our targets are one-hot encoded, we will use `categorical_crossentropy` as the loss to train the model:

# %%
optimizer = keras.optimizers.RMSprop(lr=0.01)
model.compile(loss='categorical_crossentropy', optimizer=optimizer)

# %% [markdown]
# ## Training the language model and sampling from it
#
#
# Given a trained model and a seed text snippet, we generate new text by repeatedly:
#
# * 1) Drawing from the model a probability distribution over the next character given the text available so far
# * 2) Reweighting the distribution to a certain "temperature"
# * 3) Sampling the next character at random according to the reweighted distribution
# * 4) Adding the new character at the end of the available text
#
# This is the code we use to reweight the original probability distribution coming out of the model,
# and draw a character index from it (the "sampling function"):

# %%
def sample(preds, temperature=1.0):
    preds = np.asarray(preds).astype('float64')
    preds = np.log(preds) / temperature
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)
    probas = np.random.multinomial(1, preds, 1)
    return np.argmax(probas)

# %% [markdown]
# Finally, this is the loop where we repeatedly train and generated text. We start generating text using a range of different temperatures
# after every epoch. This allows us to see how the generated text evolves as the model starts converging, as well as the impact of
# temperature in the sampling strategy.

# %%
import random
import sys

# Select a text seed at random
random.seed(42)
start_index = random.randint(0, len(text) - maxlen - 1)

for epoch in range(1, 60):
    print('에포크', epoch)
    # Fit the model for 1 epoch on the available training data
    model.fit(x, y,
              batch_size=128,
              epochs=1)

    seed_text = text[start_index: start_index + maxlen]
    print('--- 시드 텍스트: "' + seed_text + '"')

    for temperature in [0.2, 0.5, 1.0, 1.2]:
        print('------ 온도:', temperature)
        generated_text = seed_text
        sys.stdout.write(generated_text)

        # We generate 400 characters
        for i in range(400):
            sampled = np.zeros((1, maxlen, len(chars)))
            for t, char in enumerate(generated_text):
                sampled[0, t, char_indices[char]] = 1.

            preds = model.predict(sampled, verbose=0)[0]
            next_index = sample(preds, temperature)
            next_char = chars[next_index]

            generated_text += next_char
            generated_text = generated_text[1:]

            sys.stdout.write(next_char)
            sys.stdout.flush()
        print()
# Out:
# epoch 1
# Epoch 1/1
# 200278/200278 [==============================] - 80s 397us/step - loss: 2.0264
# --- Generating with seed: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ temperature: 0.2
# the slowly ascending ranks and classes, in which,
# through for the strenses of the most the most the stready and all the strender to the beliging that the promont to the stready the still and and the hist the menting the fact of the still the still the same the still to the stready the still the become the most the manter the gradication of the the strenses and the before the still the a the comparity in the compally to the promoned to the restint to the fa
# ------ temperature: 0.5
# the slowly ascending ranks and classes, in which,
# through for the need the conversions to should the read sumper a some and almost the contentions of what he "other in the perhaps and he mensto do in the incts as a man of higherstred the compain in the interparity and the procomposes of the instander
# of a getures and some a doman things to the religions. which he is the content religions and man as the sensity to which he distime the the interpain the stre
# ------ temperature: 1.0
# the slowly ascending ranks and classes, in which,
# through for the zispoution.
#
# ypt that it colfecower upon thw was medelyged to suchally postion. sonte that,, when oue lonestading to befoneves contraged and remare which he
# thence
# a great
# as resiefurion.
# the nadwally alm prihopited and -if i miteray, as a strught,
# toot have gose to an men on love is fortwerwate, of caurting indeagise if a conmancing
# more ang
# facugrinies! and unestiffer
# enou must to soble on
# ------ temperature: 1.2
# the slowly ascending ranks and classes, in which,
# through for inreelies:-lise, bedin-bsili, whatafcld-, just
# desilt to them ha1 dostym. and he, of which hy of goder prdes oice his mager--ogenicals efeors.
# persosing--uronly love aidorment of the dubestluing and in germal persomfaitionsof. ibredueail. fam  as facaluevinentained,lige one ture and undedutour lhiw. echofed as a menticcous, compay be duesoadd truch a so finds of "butver. it which mavicaty ulporq
# epoch 2
# Epoch 1/1
# 200278/200278 [==============================] - 79s 395us/step - loss: 1.6448
# --- Generating with seed: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ temperature: 0.2
# the slowly ascending ranks and classes, in which,
# through for the sensuting of the sensuting of the such the such such such to and the sensuting to the contemnt to the same and societ of the sensuting to have been the sould the sensuting interedest of the sould the sensuting of the sensuting to such to be be the sensuting of the sensuting of the such to the sensually man and society and compare of the such and man and consider to and the believe of the sen
# ------ temperature: 0.5
# the slowly ascending ranks and classes, in which,
# through for comparsion of the subtlusions of the science of the believed and which has reside of his pretend the such the believed commining and the manisted of man inverstany the beal everything it we can is individual, he antimeditions of the uncontention of his such and intered to and doring of the very some has god some make this sensuty and be the racies to soc distrosined of life, the ritional himself
# ------ temperature: 1.0
# the slowly ascending ranks and classes, in which,
# through for ", a
# lead of the let
# sigjet or
# "ates and
# this sees under the 'nacher nece,
# naivation. and authoruen
# marks of himself around inventions, treinge
# wad itself
# memoraad: the dover
# makin "goirgh
# ther qualturs, utwisht.
#
#
# 13! ; as continual! ob shaking affared, as equally far
# are that things,
# timselved of god of vortumisty than pridom. ye is henality of man" the themenous
# everything toonist, whu woman
# ------ temperature: 1.2
# the slowly ascending ranks and classes, in which,
# through forth,
# charays on defende for the pleasure xeltisheson, los uncomple e danarul arbition artivulable individual,
# we ofristroricy combondenal,
# makin: the batble.
#
# 12t. afthing aidpishance, abithous outwisiong. troust
# free of relied to to dosrined, is he say steld
# mately
# mystectly here ivors, and badily
# nothor of homsinaulal and wor, may hele ciyligafifichout, this clandly misderne's the veryapif. it i
# epoch 3
# Epoch 1/1
# 200278/200278 [==============================] - 79s 393us/step - loss: 1.5503
# --- Generating with seed: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ temperature: 0.2
# the slowly ascending ranks and classes, in which,
# through fore, and and in a man and all the most cause of the soulth and all the same the same the strengle and in the same the religion and in the sense and in the same the most contemption of the same the way of the same to the profound the stright and and all the same the strengle of the most case of the world and in the same the states and the same a man and and all the most same the strengle of the same
# ------ temperature: 0.5
# the slowly ascending ranks and classes, in which,
# through for the same the every solt and senses what is a matter whethers and to be the case of the very be anyohe any man
# to disconcerned and he
# protocher and something the world and itself to the spirits and the will in the matter be a atnecture and in the partorigication and because the profest in the provest and and in the desires and profound to desirate out of very the belief and with a man power of me
# ------ temperature: 1.0
# the slowly ascending ranks and classes, in which,
# through for in souls and upon of har understand: one asmost the duinguish to "the emanntifred inthantise if the corment the worth, both, as affarren--surpast of mank--we feilowings something of cherast called
# anyic notrough and such at mo be the is adliculisiouses
# in acknowlyne handication, and in to mudingness impociod. he yentange, what a prohe, a woman, are heart was spicites. the precies and concerts bu
# ------ temperature: 1.2
# the slowly ascending ranks and classes, in which,
# through fosts, therefist.--wpatf!
#
# north, my
# be"lishing the disneritions--"beco gud intraco-de breabing remante to responnieal eventus adofethre? to a
# person-too gennarious, voltnoctors atother of itself wult
# shothses ps no
# oremis of light
# inleness toove.) of lpuce, gramic
# fact ary therem, alto anre; whethrenests evento, intells knowledges of preserss--is in more
# which, a tronds--negralful estrity. lou twom
# epoch 4
# Epoch 1/1
# 200278/200278 [==============================] - 79s 394us/step - loss: 1.5030
# --- Generating with seed: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ temperature: 0.2
# the slowly ascending ranks and classes, in which,
# through fore of the same as the same as a problem of the same as a conceals and the same as a man as the so as the same as a problem of the same the same as a man and stophers of the same as the same the world and and the same as a state of the same as a science of the same as a soul of the same as a state of the same as the seems as the same the present to the same always be a man and state of the same in
# ------ temperature: 0.5
# the slowly ascending ranks and classes, in which,
# through for evils and eventhing the reason is so an music and subjuctual state a constiness of the fact of the earth, and the same as a fast of so is a man as a generation, and sense of the properstical judgment to the same called in the herules as the world and consequences or as
# /home/haesun/anaconda3/envs/deep-learning-with-python/lib/python3.6/site-packages/ipykernel_launcher.py:3: RuntimeWarning: divide by zero encountered in log
#   This is separate from the ipykernel package so we can avoid doing imports until
# a greatism and as a differents to a mutt the have destrue as the things but the constrained in the preceation to the make the re
# ------ temperature: 1.0
# the slowly ascending ranks and classes, in which,
# through for mankinds and .
#
# faultive the been overdake of sprembal the one impectlat, in the eterent to re. the religions land an earth. under its law milfposting its curiestayed point, if i good in
# the reaples set whe suid; of the weaker. younomination. us itself-binds and be every stcole advane of still motic incertainiture freelopmens evenswhethy can fact eperulal in difficulty,.
#
# mining last
# in himself
# ------ temperature: 1.2
# the slowly ascending ranks and classes, in which,
# through for us. if fithinc"--arts ma of agaily its own rulspications at noh re pleamner
# a good object of
# meres on tlong,intionbleard: what, may inor think of degriexce. therevilitive of will, heol-say somethings
# re-lname muso tegats which yles no rerardre signacy of morally lofty--like himself
# has any eccopacue willed -bedfisimes spows lafutsed
# flagy but
# be barts good prudear
# truthbleing--theos--nerribled,
# epoch 5
# Epoch 1/1
# 200278/200278 [==============================] - 79s 393us/step - loss: 1.4722
# --- Generating with seed: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ temperature: 0.2
# the slowly ascending ranks and classes, in which,
# through for the such a man is such a man is not be the probanes the pation of the present in the such as a probanes of the present be an action of the soul and the man and the soul of the same something the probanes and something the have all the most conditions of the such as a communition of the sense of the power of the power of the power of the subject of the such as a man the probaients of the prosessi
# ------ temperature: 0.5
# the slowly ascending ranks and classes, in which,
# through for this in the power of all perpect of the domarity. and compared as the spot and the vacient that they are great all events and cases of the greatest and for this converse. why are some has not think of the distrosity of the subjection of the pleasing of the distinction of the himself is not pathers, and the noures of the souls of the mastery of the person person who values and allist of the
# prese
# ------ temperature: 1.0
# the slowly ascending ranks and classes, in which,
# through forlifect has woman, they
# endowarde of
# regeluble finds togiat get mind their mitridation, and be diseines "establisity.
#
# mations noble impraiend.--taste
# floow
# away uncorences of musict is lick! which, be spirits, they .
#      mie of one, accirnt, on found grow of the seem to they would gaolthum, with -at perhaps in devilition, they been" to bet created be not all accurately noven, assessitu, xquivite
# ------ temperature: 1.2
# the slowly ascending ranks and classes, in which,
# through for objected by imorst,
# for an efic europe which degriously not oulp. ikeephers
# must is
# this capaniacy,, hul.
# to ruckly
# cypoverity of ordey will on, cad eselves the have rom
# brusphys, god! it now are,-or is,
# means in from philosophy, for were spirituring there, weaked: they calowitious real so fir in a all this riviging mankinly fly,-mans of such as it was as shound judsian spinina
# valuation of the
# epoch 6
# Epoch 1/1
# 200278/200278 [==============================] - 79s 394us/step - loss: 1.4496
# --- Generating with seed: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ temperature: 0.2
# the slowly ascending ranks and classes, in which,
# through for the same a world and something of the seems and the sensulity of the way is a more strong and self-convertain and some the sentiment and prompting of the sentiment of the same a distrust of the fearterity of the strong and strong and destruction of the same the world and sentiment of the secuerty and sees the morality and still of the sentiment and distrust of a distance of the increase of the s
# ------ temperature: 0.5
# the slowly ascending ranks and classes, in which,
# through for acts and distance of the subjuct, it is the see had the period it is a promption the present of the same constance and bother the to expression is now be possible and subject of the world and the discoverity and propense in its instinct souls and believed in the soul and promess! his contemption is also the greates of the deligjude of the taste and see the originating of the really all the still
# ------ temperature: 1.0
# the slowly ascending ranks and classes, in which,
# through for upon truem--she what far nreeding scientific to potiticlies.--in the
# immensural, in fact: live fust the weaket an errorgely, which makes more accordaner. at lighual
# ast an early spirit slowled would has a ronter artis and inspection. in succe is great
# has present anything there he is also ids of the
# has have a fortune--with the estaves, his detireis of to one gaila,
# others"--as seldt is. and mor
# ------ temperature: 1.2
# the slowly ascending ranks and classes, in which,
# through forstorness--why
# the "preoratesly
# as? i my good de phool bad "are althing opleast
# high-diven meot all, only the reads
# thnaud the timily. those certain its puot
# !".=--enlignerss of nature of a morals
# of which
# the
# charactorsly
# question, and reyulling swilt its weakenaness; grieft-, which forectheus "vanntness,
# succambine. their to my tragrain
# wither
# as art is scrormezfinn prebapi"s and side with grego
# epoch 7
# Epoch 1/1
# 200278/200278 [==============================] - 79s 393us/step - loss: 1.4342
# --- Generating with seed: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ temperature: 0.2
# the slowly ascending ranks and classes, in which,
# through for the pressible, and the sense of the same the same the soul of the sublimes of the sense of the same a man and subtement of the success, and some the most conscience of the seems to be some the desire of the same the truth of the cause of the same subtrible and the same conscience of the pressible of the same the sense of the same delight and the sense of the same desire of the desire of the same
# ------ temperature: 0.5
# the slowly ascending ranks and classes, in which,
# through for the servaling and disclusion of the suberfect of the discourone in the same dearned the deceation of discepress be some to a properly has a dispressions as delight the seems to the
# sound barbarism of the servally decession of the soul of the same indication of the most conscience of the pressible of the before before the man and the same there seeks to circums that the constraine and discernes t
# ------ temperature: 1.0
# the slowly ascending ranks and classes, in which,
# through forceous-greation is far is they necerse the greek? the hald
# causes. and
# discluds uponseluacing
# where he feeling
# of actionsing ovisting. he
# who suffers, so totarily exertignessur of certainness mone seek of praised some bacried pressive same for towila and dullay to seuty sought destroyically probable callt dice sholosa
# an we had a condect of one is the daserste's and ha lo recognizing style, whome
# ------ temperature: 1.2
# the slowly ascending ranks and classes, in which,
# through fooliahed that adtum timesation
# of an among upon to dut saveable natically whether which that excause it sleally belictipds to medeaget". hey neers of lettical dabrepticy dod
# itsichoum, havingpmen). compruchs of long, would there
# are our secrebtely upon the placef
# natureaable carequency any by whomoce vertaried
# fromaming . errives ssia occammen--from opon is
# his soully, and peat arc! for the saming
# epoch 8
# Epoch 1/1
# 200278/200278 [==============================] - 80s 398us/step - loss: 1.4218
# --- Generating with seed: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ temperature: 0.2
# the slowly ascending ranks and classes, in which,
# through for the most power in the subliment of the spirit and himself to the spirit of the same discourse of the subject of the same the soul, and and the discourse of the most stronger and sufficient of the standard of the same the world of the senses of the world and still interests of the standard of a man of the world and self and something and and sense, and the senses of the standard and subtle and th
# ------ temperature: 0.5
# the slowly ascending ranks and classes, in which,
# through for the same the rasine and disposin of stronger the discourse and stoon in the world to the worsh and for an opinions, and the most being interests in which he sensegoby of the doubt and in means of the dougness, and he is not one called by a great the life the man sense of the laber impires is itself about the all the present considere. the self despensible the values before with his time and
# prov
# ------ temperature: 1.0
# the slowly ascending ranks and classes, in which,
# through forget in our knonced.
#
#
# 1menad a
# stequent of seguination of
# dr-all the belie sied.
#
# tderraby
# sald shoild sufficient, uswables and upon their authjecically,, and as original racichessulty express his
# independany ity.
#
#
# 12sy duringer thereped ssireg of a neart," the means, and capable understanding koidamous
# wishoususing where is to mediely at of and barings hought ideded, advanct are sellow--whan on
# ------ temperature: 1.2
# the slowly ascending ranks and classes, in which,
# through for act vage by tide withes a meppistions) of being. inteivil has finr equal istaken itself indiciting anyon,
# wid cone-cureoming voldur furnately
# come is" there, and has mecise difference. these b scicutibllemed to commment, or patined--that
# earof or case, a corvectuable and ratisc missified ?bull, someoned else
#
# how privilet"-omarce is regate
# of through
# and judgmentratles with loftings,
# row just :
# epoch 9
# Epoch 1/1
# 200278/200278 [==============================] - 78s 391us/step - loss: 1.4100
# --- Generating with seed: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ temperature: 0.2
# the slowly ascending ranks and classes, in which,
# through for the subject and subtle things of the feelings of the subject of the subject of the problem of the partion of the properable and the properable to the fact of the properable and the fact, the promise the powerful the proper of the problem of the subject of the subject in the destruction of the subject one of the subject and desires the promise to men and and the world and the possibition of the s
# ------ temperature: 0.5
# the slowly ascending ranks and classes, in which,
# through for a pain of the
# made advantable man and subtle the experience of the problem of the religion from the properation of this world fain and discovered there in the contempt and propernation: the expedient of the promed the discovered there is a sop an attempting and "god; the perhaps always have sense of the "contempt in the means and self-grance the attartion having way the possibility of a man with
# ------ temperature: 1.0
# the slowly ascending ranks and classes, in which,
# through for beliece and not veritre, learns upon the respections, with our for the claved into deepen, continuing withouth, enjoy wyposees: and revoluntarily poyede: there ao fait bodyeds than senses--the europeal value of him at infurent, and
# discluring ago plachiful, doubling the
# able tendeion
# knoble in them, from us the omy and diccives rowich. our our stand the varm to adventadia, by the spirit, and usu
# ------ temperature: 1.2
# the slowly ascending ranks and classes, in which,
# through fore? eadruscauses yle."
#
#
# 1. but our of "most hubler. that he ylehinat  much
# himself. who lidele life all "that wave were knowledge means, we prepanation--commairality: finers faces, morulonful, "more,
# ways
# essuptness en possibility pull man of difficult
# that is ethase it, taken, for he hamostealy theoul in the world problan faith
# man mord
# atmer to moral justimation, an in thousd to takes name." i
# epoch 10
# Epoch 1/1
# 200278/200278 [==============================] - 79s 393us/step - loss: 1.3985
# --- Generating with seed: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ temperature: 0.2
# the slowly ascending ranks and classes, in which,
# through for the most course is a more the sense of the world and society of the sense of the sense of the same a man is a proper and society of the constance of the seems to the fact of something of the proses and the proper of the sense of the complemination of the most conduct it is a proper and sense of the protection of the world is a man and believed and in the serious conscience of the same sense of t
# ------ temperature: 0.5
# the slowly ascending ranks and classes, in which,
# through former sense of the desire such a personal allow it is be an of
# an another its "good conscience of this desires of the stand has defeniation of a man is a word to the most spirit of nature, a paragion of possible of
# the spirit of the false allow has been opinion, where must do not can is a means and the sense of such a counter--and who is a hard in the faith, and desire in the present in the more in
# ------ temperature: 1.0
# the slowly ascending ranks and classes, in which,
# through follows, are a other, senses (or in virtues of a distingul of what makes i begarmed s
# grake--it is timap course of the look withor it much isharent--however, where
# foolsoming: the cha is permitt of a poitonf--european wind stome it will just one slaty. to pened "a historied only me the voeter on every languagled express
# moral will winds one and having from a sone--he feeling,
# is ane the instronaries
# ------ temperature: 1.2
# the slowly ascending ranks and classes, in which,
# through for the mate another--it
# may unifession of
# rungleached help"e:
# on order to the mestarmed againstemess. relatity fear and somethings
# (trahert-
# sthood when, i coniames firse wen
# e willyth (why callde's namuly a s
# more that dole-tole laoke in allierne:
# it has always love identitily times, convert husichly--carety just following. on the feets too sokeng towreasons oppaning from poins.
#
#
# 254. it too enjo
# epoch 11
# Epoch 1/1
# 200278/200278 [==============================] - 79s 396us/step - loss: 1.3889
# --- Generating with seed: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ temperature: 0.2
# the slowly ascending ranks and classes, in which,
# through for the spirition of the desire of the struct the conscience of the strength of the state of the could and any present of the struct of the expression of the dead to the struct of a soul and sense of the deceive and the state of the problem of the states to the constant the conscience of the same the disconstant the conscience of the struct of the world of the conscience of the present of the streng
# ------ temperature: 0.5
# the slowly ascending ranks and classes, in which,
# through for one should power of a sense of the strulmates of the last the existeding of the sacriffulness, in the standard. "the world, and still problem and more to our perportion, the more and conscience, and suppose of the couls for the fact of the desire of could indianed affection and conscience of his present with originated could some a
# conscience is an originates to constant the good and profound wh
# ------ temperature: 1.0
# the slowly ascending ranks and classes, in which,
# through for unurmy will all see the senseltice
# soural his example of his forwain-corverition, and and sessity, notre arers and crueloly elevatent precisely these dog"s; that couldless, it is that you has an ourphity to metaphysicles
# and sope of the ainties.--thus at, moral teless. the one, through of gof.:
# fyos to first themselves itself as a convent and self-present with youthse be a look one dighiblantal
# ------ temperature: 1.2
# the slowly ascending ranks and classes, in which,
# through for tay to
# nerge, socaling
# of present, actutns. bith voluna yetablishw). have worted
# for the full of wagreound
# himself in reasons sensations of ome become the viewnce, however
# him.
#    but a divinate or imperuates
# eventure casty, onhal of the disclod
# yeam is does no tuars of ided
# , olbant of
# feeling an irtoos the togain its form, thing lauggly redign med to first younk" unknons, the intuphisies. in
# epoch 12
# Epoch 1/1
# 200278/200278 [==============================] - 79s 396us/step - loss: 1.3820
# --- Generating with seed: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ temperature: 0.2
# the slowly ascending ranks and classes, in which,
# through for the present possession of the problem of the problem of the more intellige and the most power of the most party of the man in the same the soul of the man of the most go of the present the soul of the problem of moral problem of the man in the present desire to the same the conclusions of the man is the conduct and the more the sense of the fact of the man is in the person and the conduct, and t
# ------ temperature: 0.5
# the slowly ascending ranks and classes, in which,
# through for the present and world of the fine be one had as the men and developed than the belief which is dominity, and the world and desirable course, the present hestarile that i case of the intelly the most possession that the man in the face of which a more perculsitian in the pare state of the surfation of the are in the praise that i view of the fait man souls in the existence of the heart, of the ea
# ------ temperature: 1.0
# the slowly ascending ranks and classes, in which,
# through for the bruap", kemplat caitly, very to psihe asmotated
# how in the rule
# and to the thuse physitiance germanity, however).--but which for the world and confines by less out of
# question who europe sympathy," and was his tranigasontiby christianity, the other doubt more hears "feas measive and suffer
# has
# vary word residd who know they he thoughts: in roce.
#
#
# 7ivy oyth to general. this charaches havinin
# ------ temperature: 1.2
# the slowly ascending ranks and classes, in which,
# through for omewainanest godody has decad
#  go hhfore derour makes your say, autial textept rovering strebeiciousnifemness to pmety my zings longing frind "tradition, theses modern of
# slre such syptramance. dully-nar
# ,urounged. for wooted onestery when us interppeationply its languagi, naturalily
# and shir examanally
# coming authonghing,"
# in have
# by let indiverius," with a destructian find
# teste. yesterment t
# epoch 13
# Epoch 1/1
# 200278/200278 [==============================] - 79s 393us/step - loss: 1.3749
# --- Generating with seed: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ temperature: 0.2
# the slowly ascending ranks and classes, in which,
# through for the same the moral conscience of the strength, the moral power of the property of the spirit and state of the fact, the moral strength which the world as the father the promise of the states in the strong also the strong in the strength of the spirit of the strength of the states of the states the same the present of the world to the restrict of the strength strength and the property of the stre
# ------ temperature: 0.5
# the slowly ascending ranks and classes, in which,
# through for the best powers of life, and the same
# treated the power of comparison as in the greatest be belien to oursely the art of granderates a
# moral time in the great the astrained the lord that it is also the moral condition of man mucked the day evil very things of forse state of the constrainer to the one this matter for a property of the restrict of the strift, and the
# greatest morality. which the c
# ------ temperature: 1.0
# the slowly ascending ranks and classes, in which,
# through for earth, he had what he speak dominaties of this
# simed good were more often, the scvolo-approbence which how cleart may internour his suevers to
# determinatedely upon the polisical above and works untedain into feul. the ascortorty for whole
# exceptional others
# is adocture in them: in a littles a metholem prases and close
# man ever state en everything besu good reverention. for their foundest, and du
# ------ temperature: 1.2
# the slowly ascending ranks and classes, in which,
# through for good ,a better obligence (and
# them, traus
# etheb. he hushming, he imorsh and
# characterablity; ass is
# the prebeant grace. unvertrant, inviopred o. stepoly ofsen, respectarity in loving of also dangers, a go
# xders still breedous fintiums, and the chener cons much get enough my only not are furerpschangly
# generat in purdion inexcept indeed
# nace of result, the orners augustedd, is pain rubordivelaier
# epoch 14
# Epoch 1/1
# 200278/200278 [==============================] - 79s 394us/step - loss: 1.3690
# --- Generating with seed: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ temperature: 0.2
# the slowly ascending ranks and classes, in which,
# through form of the fact of the spirit of the precisely and mankind in the experience of the senses of the spirit of the contrary and souls and the delights of the experience and and the manis of the present of the senses the senses of the same discerned the senses the present of the individual the moral being the consequently and the same the same discontect of the experience of the sense of the present of
# ------ temperature: 0.5
# the slowly ascending ranks and classes, in which,
# through formuling of the expression of the experience only and the only of the constant course of souls and more religion of the morality, and with the comparison of the free spirits and precese of the sense of souls the fact us a particure and the artists and pains of contrance to the spirit has been made and from the fines of the sense, the presence, and the word and not invering that the entiens of the v
# ------ temperature: 1.0
# the slowly ascending ranks and classes, in which,
# through foreening problem his case whether honlies of "secon: a
# suptingh with he locivity: the
# souls, hence entiens, psycholde, suivilegred of the spirit, as think has almost
# forimity, but ascet the right of fapare oft immeatious and by self "ancient tlains of a namen
# ablaged, the weakers and
# as he extent, as we knows as purposty that long to recepting atless above all that a same believed
# man, came sunfers
# ------ temperature: 1.2
# the slowly ascending ranks and classes, in which,
# through for the obstemcity-diagonal
# stotude
# immortical rights, the vemaases, every shighed bfouthetfuender-name, excitional cause, this if philosopy pasker awadem of the laighte judgmently willmon, she dispilticured respontition, he he seek reseld; althing to others
# with nevers of
# ever art say, that to rest a god, overwherition of the belief so tradition
# bulk" to his
# oneself" of times, their devery to belie
# epoch 15
# Epoch 1/1
# 200278/200278 [==============================] - 79s 394us/step - loss: 1.3637
# --- Generating with seed: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ temperature: 0.2
# the slowly ascending ranks and classes, in which,
# through for the sense of the sense of the good and so that is a man as the sense of the contemption and the world and the sense of the world and all the soul, and the contemption and the sense of the conscience of the all in the self-contempt and the sense of the same discontect and the man as the father of the sense of the same superstitut of the sense of the sense of the most self-contemption and the cont
# ------ temperature: 0.5
# the slowly ascending ranks and classes, in which,
# through for the most comprehend of the subject
# which is to a man of the truth a radical soul: but is have to say: but the consequently and desire to the most self-came of them and some strong to the constrained for the worth of the dower and summence that is be say. up with the greatest things in all disguise of the long and good or "a man at the values, when the surpliced that the effect. the compliming th
# ------ temperature: 1.0
# the slowly ascending ranks and classes, in which,
# through for ptho sideums of laverly in his case itself ow--for fearily intellectual
# self-coaragined
# in anctence, with you an
# crunc, of manse religious  from this
# almost, bebutowed lised stand of freedome. here so ideas are. an will and withinm timates w, who has once enfud'ered--the markil every with autious of never saidating means his snaves at all psychologity, or inferedine whle. it pleasure fully philo
# ------ temperature: 1.2
# the slowly ascending ranks and classes, in which,
# through foist life," angly, a let differentaf to way,
#       thiin "chol delf perculled; we break. he elte).
#
# polurice by its gof. but what one
# what music so longery to general and will affingevalices towardamp, will blond-"a
# be irenteaphetess" drawth. however, spene as nature, "generation
# of all susparding (one"
# withtu, sodes, which an, "pare that beauty suffed in times, plame not to tem of illd worch putl
# epoch 16
# Epoch 1/1
# 200278/200278 [==============================] - 79s 393us/step - loss: 1.3594
# --- Generating with seed: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ temperature: 0.2
# the slowly ascending ranks and classes, in which,
# through for the spirit and the spirit of the sense of the same a down a contemnate our strengthed to the same an additional string and discovered the sense and strong and social the same as the sense of the same men in the same an actions and souls and the spirits of the spirit and the soul as the conscience of the sense of the same at an advance is a more of the same the existence of the sense of the same
# ------ temperature: 0.5
# the slowly ascending ranks and classes, in which,
# through for the world and like the foreits in the same says a sogution of the moral his problem of the present, the religion many "moral its of the came a povent and seas to the metaphysical in the feeling of the moral times and soulstry which is a down of the there. as it was a dable only very religion and discovered the self-ages the contempt it is a heart has been soul, it is for the partious that a shor
# ------ temperature: 1.0
# the slowly ascending ranks and classes, in which,
# through for us here pare ring strict for the charming, as hitherty awayed of point to
# him of a godvance even them, impulsicration and stupers of the responsives when he see made son arcest
# profound away plained akelved individual
# things it! with the greek of which, cork sotes the lax, with this bad is desire
# cause adoich and the mon cligning oundless life--how proof the characters artis of a spirit the blin
# ------ temperature: 1.2
# the slowly ascending ranks and classes, in which,
# through for dispositions.--but atmess inrequaly, lefting.
#
# e had ou man too no
# vowed to vicility., we ilt, taly spiritual, yes, womanity.--however of
# prefepay of his art
# forugle, with surcrate of one sain,
# grateful, feas with all oneing of rover-all his creatovla audding lime spet bahtening up among his own except in the way after the greatedly pous). by the collent--the law weven the accooflentive,
# a emtev
# epoch 17
# Epoch 1/1
# 200278/200278 [==============================] - 79s 393us/step - loss: 1.3546
# --- Generating with seed: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ temperature: 0.2
# the slowly ascending ranks and classes, in which,
# through for the man and the present conscience of the manifest and so that in the conscience of the property of the conscience of the senses and and all the and some and the conscience of the present on the present and precisely the conditions and conscience, and the men, the conscience of the man and been the belief and the intellect of the problem which is the sentiment of the conscience of the experience
# ------ temperature: 0.5
# the slowly ascending ranks and classes, in which,
# through for the self-production of the conscience, the experience of himself and been some light which we been sense of the precises and in the birly not to have been bound of being expression of the souls to test in one cons, who long, the senses and metaphysical the sublimated and in the instinct of the solitude with a belief and been in the attached the desires belies in the values, impressnes and in the
# ------ temperature: 1.0
# the slowly ascending ranks and classes, in which,
# through forad
# something in the philosopher. if
# the intellect only of the attaine, for the
# conk dave dos is ononets,
# that
# mant. to desent, the yortness it is
# a defle and he foot, if the
# free spirisually also all wortnes," and in the questions
# of to the work specially-mfortrioks which content free to the lattery gerquence of whom man, has greek to subtle!
#
#
#     be that a clumsy provers, the entiredresse so co
# ------ temperature: 1.2
# the slowly ascending ranks and classes, in which,
# through for hekementnt, sbul ylos was-debumble power supmitate one's
# eurtecle law will liy
# jesopective ivpenensiti)!") for   voed in
# the dis upgeniused "e, the
# rateprath; an instvigius and fearlish,
# mourater
# tokenness
# perclosporden, domela" highest
# disglarg
# say, or, less and
# egon for law-hud
# entablevent--like taking
# the radiculted and
# somtworal creasoming farsom all
# to inamblisating". old as know thought a
# epoch 18
# Epoch 1/1
# 200278/200278 [==============================] - 79s 393us/step - loss: 1.3496
# --- Generating with seed: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ temperature: 0.2
# the slowly ascending ranks and classes, in which,
# through for the same the soul of the soul and the sense of the most conscious there is a man should itself and the same them and self-problem of the sense of the sense of the sense of the stupidity of the consciousness and deceive and self-problem of the sense of the sense of the present of the same the present of the sense of the sense of the senses to the present of the same the sense of the moral the sam
# ------ temperature: 0.5
# the slowly ascending ranks and classes, in which,
# through for it is the worst the good fundamental predice understanding such a morals, in the generation of a proportion of the morals to the fact one of the world as the sense of one of the restruate belief in the work to possibitating consciousness of the other of man" and sense of placing the fact the same could means of their degree of the suregure of the staking the generation to the representarians and
# ------ temperature: 1.0
# the slowly ascending ranks and classes, in which,
# through for one withoute, or "we ie misdonacably "more god: there is best now in thousane in the nee
# understands every with generaticsk,
# for one born ignovance to "placious lruputhely trousst-rible for finerally notaily
# misingations along is be whol
# we feet its unwistable extent in the guil--and actions even circummated action--most emoty constant hads aw he will itsten and religion clear most free, and sov
# ------ temperature: 1.2
# the slowly ascending ranks and classes, in which,
# through for illowing? has riotsgay
# is seeks that sure, with hunt to have his enlicia and plant penilen of justice formulnones. forting is awajely upranciates.. by precedxceiness and sort "virei alsowe, which perceives
# here of voluator.--but for the sense of this philosophschal of thorougated priesesirest.
#
# roy devils else
# of omcebnistmen
# and conscience of "fairdleegs of liceg upways in order to predice obje
# epoch 19
# Epoch 1/1
# 200278/200278 [==============================] - 79s 397us/step - loss: 1.3458
# --- Generating with seed: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ temperature: 0.2
# the slowly ascending ranks and classes, in which,
# through for the experience of the struggle and conscience of the father for the soul and the struggle and something and the spirit of the spirit of the strighten and more and the moral continually and the same the sense of the same the sense of the struggle and conscience of the spirit and the spirit and the spirit and the spirit and the spirit and the belief the spirit and conscience and the spirit of the
# ------ temperature: 0.5
# the slowly ascending ranks and classes, in which,
# through for it is a standard of the whole and the spotist of the contradistence of the other of such a proposts of the existence of which in all life and soethness in a discloses a god, of the spirit in different be good from the good to owing to the existence and different which they are now to say, and therefore are there and a discovered to owing of an absolutely deceives the chance of the and man of eve
# ------ temperature: 1.0
# the slowly ascending ranks and classes, in which,
# through fors"--as he venitician
# impirpue
# that he sighting, with their goodly sympathy. so soece thrgete philosophagured ou requipce of with a depth of the regret, with an and wumbs in every know any, no not value and religious. the minds--for the geur of something optilated, it, actsy, togeasherzater thmates idatian, arhing of intilest time--a lingent our saffucus heprarifal
# related of their similar form, t
# ------ temperature: 1.2
# the slowly ascending ranks and classes, in which,
# through follers of forgering from by sacine of in more
# fmimly such a negerth in a nothip thembrefulness sublines more, moral. how uneir ester
# precisely too long
# a whole help. we now gear hober'is
# respect
# in itjuct if the own scarch aminisory and wound
# us spoft wauld, on the follered thnoulh"; with effect, gooship in volualision.ed it is not certainedhess endowly
# something. any blegable, if bn(a philles suff
# epoch 20
# Epoch 1/1
# 200278/200278 [==============================] - 78s 390us/step - loss: 1.3423
# --- Generating with seed: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ temperature: 0.2
# the slowly ascending ranks and classes, in which,
# through for the fact the free spirit of the senses that the senses of the fore, which is a proposts the present himself and allowed, the conscience of the present of the sense of the fact that the most delight--the most present in the same the present the spirit and the present the forming to the most desire of the sense of the most spirit of the senses of the subject in the philosopher and society of the s
# ------ temperature: 0.5
# the slowly ascending ranks and classes, in which,
# through for the respective to the spirit the whole assumed" in its
# superstition is considerations and hist be state of the moral happiness of the most charm of the subject suspicion to the whole the fines a domand has men, and
# in the same the promption, the contraryom the great religion in the world distance of the present, in free spirit can be does it period something which the most belief of the most phe
# ------ temperature: 1.0
# the slowly ascending ranks and classes, in which,
# through for good re would =fore! equalbived and just imagine lie, some adddings, and so slave, far bleeties prehansibyoms is misst-moral type as testeneduch!
# becauate all feelings? limical pains at olo with attempt, a dexial,
# and become an action. thou an philosophers is a pretends ly haf orport of domand more ackentards of zed the foreur into sharcer,
# and on
# the pride believe
# and case of experience, as
# as
# ------ temperature: 1.2
# the slowly ascending ranks and classes, in which,
# through for cror
# to be surbofty. they givis resuals cleetingalsk, ccatuvg hely, then, of have subjectsalily and subjectial, the seiblieith: past the ubserriates all spring in him,.
# proper apotioustlivg, from europes
# and tentionalise
# the
# oppositive ultaphy finds emotions, all suffering, germmgnarces in himself., however, appeatories of ma an iczusal worldlessly a mast-point artist celisser,
# castee eebieds on
# epoch 21
# Epoch 1/1
# 200278/200278 [==============================] - 79s 394us/step - loss: 1.3389
# --- Generating with seed: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ temperature: 0.2
# the slowly ascending ranks and classes, in which,
# through for the present--and the spirit and such a new more spirit of the self-constant consequently that the subject to present--and the fact of the france, and the spirit. the precisely the sense of the freedom of the sense of the sense of the freedom of the fact that the sense of the spirit. the intellect of the sense of the present--and the account and the stringle of the strugterity and suffering and s
# ------ temperature: 0.5
# the slowly ascending ranks and classes, in which,
# through for the intention of the earth the man for any terned to conscience sake of the subtlety and ready more and deceived and distingus of intellect of which the proper their instinct in the conscience for the superficial and continually
# most pain in his power and the most with the time and the whole self-denian for the person all the product
# and self and regards in a dreadful and in the deeped and intel
# ------ temperature: 1.0
# the slowly ascending ranks and classes, in which,
# through food wherever nation is constrantion. because the knowledge and su voed.
# my juststles of givened by which helf
# housabhie time wordsict.--speaks and the world ender with the preparently the
# intrigil, a love,
# snared and that their "germans the extentalulity divine superstition man.
#
#
# 12
#
# ehon, what i first the highly motive, "egut that they therein. my to be net forms (of an time too earsely much to e
# ------ temperature: 1.2
# the slowly ascending ranks and classes, in which,
# through fourayow: now, towarmed fgors for man--fortority--neighbet
# phenoment -itself (su': levef nothing misasse-; hocked onrot':--and if for interenct-du
# is crinise benehs, they us and gnants unathery of delissic
# is "finds aed all day beeng,
# refistlession.=--also cruelimy, shounding, van things of a po
# is "mode to order him. the
# conditian estrelsimy, which grimin these
# meverpoes the fragilate
# compare froms
# epoch 22
# Epoch 1/1
# 200278/200278 [==============================] - 79s 395us/step - loss: 1.3362
# --- Generating with seed: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ temperature: 0.2
# the slowly ascending ranks and classes, in which,
# through formerly and the states and the world and the world and the senses, the moral proper and the philosophers of the strength of the spirit of the world and the world and interpretances of the world and the strong one of the contempt the stronger and the moral faith of the senses and the origin, the moral problem of the earth, and the strength of the philosophers and some the senses of the strength of t
# ------ temperature: 0.5
# the slowly ascending ranks and classes, in which,
# through formerly believe where all every deal of the contrary althision seems to an antition of the same a surveduthing of his position it is also the european the class of the dispanis of mankind, and the teled to a convession! in the world, and the strength of the moral on our external the partial refined virtue of man will all itself and still because the souls worth. which
# difficult to the honor of purp
# ------ temperature: 1.0
# the slowly ascending ranks and classes, in which,
# through former artiates only subertly
# alever itself--where ling in consequent that which belong. to be fair oppore the primites e
# individual altula,
# fingline, they lower fellows ever difficult to me"--which, and some europeness--this timehe any worldle taken of escensal german arourd, or nothing the other singly invalual other spirit and all their modern and the affording,
# hand--what is happiness, for chris
# ------ temperature: 1.2
# the slowly ascending ranks and classes, in which,
# through for, in the semotion
# pridentative words explanies. the
# bemour all beforarly onetrance. it is leads
# hto, it defere; the
# germanity better vision"
# flaption,
# thinfs feated
# tafi of hely,ing the inares fron
# uned and cotumingerwor lead grack of like it pations"
# useft word
# the imply lock aretufal
# finers in t, look
# over the free
# purpommance)
# sout, vermon of odiging, and danger of all feily; requires, dangero
# epoch 23
# Epoch 1/1
# 200278/200278 [==============================] - 79s 393us/step - loss: 1.3338
# --- Generating with seed: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ temperature: 0.2
# the slowly ascending ranks and classes, in which,
# through for the same will the most philosophy of the same his world and such a person and the superstitious conscience of the most philosophy of the present of the sense of the same the world will to the sense of the belief in the position of the same will to the belief in the philosophy of the philosophy and something in the world with the fact of the philosophy had all the most spirit as the fact of the h
# ------ temperature: 0.5
# the slowly ascending ranks and classes, in which,
# ...
# th er ionon ouri  not inwt itre xlitiahirl  oai:y iner t athehe imerdaher i th  lui inm"ea tt tthid enerr t
# ------ temperature: 1.0
# the slowly ascending ranks and classes, in which,
# through foroo i(atesiontiiriiaere dr  l ndoinoer  in  inm nennthe ne elw th i  l sis ate dnen esrhs rd  o a
#  ehtis  ihql erte oonatho o hliee  erorerresahonarn inninth.ireei o e othesuie rilie  shiren qn otil th   tn ninop hte eenorunan n  aterahtnece en lrarai li
# oenet  in ts ouo th  uosilu io nn  ilo esto shs rrn i raat in onn uiiir tdelaesorine and ratise ittr dartie e o e hthint
# iarr easeida aos tur o
# ------ temperature: 1.2
# the slowly ascending ranks and classes, in which,
# through foes els onse onueanrirkseoee oe  tsthtlt lle  t aaal laneueratrsoostsotr dtheoairaieil ris toitooe iatchuoutherdsriosonsral treatsrrnolira  x  ioairll at ralryronsannti  s ne lte srws thoreni t etqsolah onuz thir ursothii aathora- athaboattlhs eitio   lonsalise en  i nthamre  uerineanane ueuusrreiiie tdtr  n e s hieh oirl uhohqale oa e ixtinianno i.iateo dinaoec  rtlnih toaerinxlnntslr ni inlndsula
# epoch 53
# Epoch 1/1
# 200278/200278 [==============================] - 79s 395us/step - loss: 5.4492
# --- Generating with seed: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ temperature: 0.2
# the slowly ascending ranks and classes, in which,
# through fo o  t ehen tht atn tt eone th t th t n n ther tnth  t a oer o t t tee t tl antor an t o the s  t t e ther o oe  ate a to s th et t non t tho tt the tlt the t t non  tr aone a t o o thntnot on an thin in te  t he t tinthhe o th t the tt t n t the ont thn e ihe  the t  an trde the t  th t t n th t t on th   t th t a th on t herent nou the th  r th on th  te t al th the tho the  t  the he te t the t
# ------ temperature: 0.5
# the slowly ascending ranks and classes, in which,
# through foren ten te  ol ort onie ths t  t o eothe at oerop e  e t aon eoe a a rert ht thin tors i  aone toa ioattesrlorri tor thlo t ore trnt ttheren ar  l ontl san  ther tooh t tolo tre  t ant  ton nis r oinhto t sere t oeen n  o areens thes anhe aer an on thoros onei nt ntrt oat t ioreuortno as ist t  te th tst tt hen tornat t ts  son ioe t re lte te a thalu an r.u uth thin  o e tho thes tsa t s ato ttoi
# ------ temperature: 1.0
# the slowly ascending ranks and classes, in which,
# through fo eh aaienet trorur  toresat  nt n t oe houas sahanrs onisl oisrn t in eols
# annose isltntlhonurouh t aeserirn io irtarra euer onhre oie r rrneutro  t shilet tntneas  etoear tanthi s erono en ahtist iala ttulut ittin  otn tslht na roa-nintasa ierat enetei eet at ittit its iaoull aanenino ti o nsso rare ton easeealilsiasrinonrruasrl o ih t ie a trelnanie e tho eotos ul ro o olerser unsat eeueustas te
# ------ temperature: 1.2
# the slowly ascending ranks and classes, in which,
# through fon irr arlo cer i otusousatoi santl eo nililinatnene ene iursoes a runtio ti  thloth l noiheteeuesttrehnarakheisiunrasos  a tenele aoninesi ena e eulliirsohitls s oloosntouatonlaneenoeito
# is aioartrerusio  s ee" ntrss h nuonli lnel otst nesltnat atn rrouirie oiitetiionno3tasohebal elanteatusretrlatohoaeaont e aresroen usiolarios ts rn rthiu   heatsrresitth oenhrur ostee ts e  oule usrthitraiolo are
# epoch 54
# Epoch 1/1
# 200278/200278 [==============================] - 78s 392us/step - loss: 5.4252
# --- Generating with seed: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ temperature: 0.2
# the slowly ascending ranks and classes, in which,
# through fo tene t n t s atet th t  thet thn  e e t te th anen e thenm ane thn t t t tn t  tn t ton th thon  o n th t in th thht in ththe ia the t t ithan  ithe t e ndens to thete t  thi ti thit nt t enen th tno  then te n n   th  a the o thf tn e n n t th an   th eno enant an t ine ien  tnen  th thene the  tunen t t ane t ide th thene ie  on t  ot t t tt ii t th in t en t en t ne the inn s a  itte th  an t
# ------ temperature: 0.5
# the slowly ascending ranks and classes, in which,
# through fo th t tndhtt tobe ttt t se son on the es atniart  t thot ath te r ndosut der enetee thins sl ts trt te tt ior iaone  e t tures ntehnop tith soe om rors oont tee tin ts tre t s ion th  te ths inntenst et n  an i o it thin te th anj re or at t sonees ate tas ane ehenanioor dst erne et  to s n  no th tis tl thuoos s t then one aesanitne te  t en rat on t on tt an t r nenonenoner t  ent a the t tonine
# ------ temperature: 1.0
# the slowly ascending ranks and classes, in which,
# through fotieoaus rli tioir ase on teon iht t ionosnss en ano in t ohehass teen  t o'eaiueoroo t anttwt nto lhe at  ien thsttonontnoouthoet itrrrnoottnt aeit t ioer o eo siaiton anaeelsaneit l t in ron  oe ntunlonsihoen n i arls anistoiouois an at  uni nteeit suiue t heroutoaohti oore thint ontt ihonnents itlooniiaten ilentonir r tns s tn tietuilsouohorlenoatsateiaeo e sneiteh s ao o terihrs  ert intitnus s
# ------ temperature: 1.2
# the slowly ascending ranks and classes, in which,
# through fosaonorahaasrs nploroet llin ntosintlle sstuiieaase tornhhishhlineritu st in entoranennlire se a tnorerionaoehanlitsndel ae or  iertuthis th nhtiesssindietlerliun ianiae tst lal ss i  ttron stieonn tisoan n rt ooitoesunitt oenen rse o titsteaneut sethoh aronre ertosltlo nnidetll ol te  i itltortotnh reitnnue anosite ere  t itseo o ien soanhe theolletsi  in as s[nturunt a  nltrin i rl ioeina alon ui
# epoch 55
# Epoch 1/1
# 200278/200278 [==============================] - 79s 393us/step - loss: 5.4363
# --- Generating with seed: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ temperature: 0.2
# the slowly ascending ranks and classes, in which,
# through fonert ese  n in  i a o n   the t ne he aas e s tn th d   le th t ee d en. t  d t ptni  the e th  th thaes t in" at o  tha made en th te t  or tcer th l he  o is de d  n   d    p p ire an    h"  thmt c  n- he th r d t thth
# ees ae w nt omre h  un t  the a  t n ade  t  ct e are  ie th inen   i o t a o  th nt to  the tnt din t ne i  tishe cne   the t he n t  nd n neon eh  an ndin  h  a  e ne the s inen
# ------ temperature: 0.5
# the slowly ascending ranks and classes, in which,
# through fo en  s r th t t der e e  t en eit e en  e s se en relez   ur h heis l  ees t   in tge "itthe st e th tt s rnrorh d tir ehdx a orr so oer neline ehe tonh  i  the n aon  hs enaan t   is n or d se thoe a e th  nurnd outerk ero t nthi or" e   o e i l n thh th  ah an teiotn  l t  touerno s aos t tt tles o e thth  t o an; thr:cner th t dad rt dth e t ie rr oo the wa-pt at denanwhih t inhe ontir lho  o h
# ------ temperature: 1.0
# the slowly ascending ranks and classes, in which,
# through foerasoaje tel rahnerii hc s tuhe eletl  thso oite    unerrer  eho isiihelibron l onoh als alri   n eoluent o on h nr trer ila  is inu trrisniut tt ea ile ahoo e s ntheerbh r toeitulir onaidt onotent aoninlo thheremlsttw s e anl ln t llo aihsie etiraire  e ansato eeenn in t rhlsah l dn tn h lioue istle  isoi rorhs erainesdoa e r ile na on t ealtrinlo.uanh aerhlouatnnc enanision ai  aher hano itin is
# ------ temperature: 1.2
# the slowly ascending ranks and classes, in which,
# through fou lat t
# ieoreeran e thajhr hentnshkosea istddat ne itl sh un iestastuthllts an limer lerslth  th t shceh rnullearen sn iti se rt narilhesuittaoruremrdereh  resthrn smea  n trlreruetat silaueetheioseislrelo  t aost ate ssontil l tir i  hd lt s setoirushoe ritoerair  t lt urousleherht aarc sa thn e tn meo  en nr ahi ohahtin  s re o thlui o oeeeorr oarttesn irusor th ndn ir el ohn  a ar t oltn hintrt
# epoch 56
# Epoch 1/1
# 200278/200278 [==============================] - 79s 396us/step - loss: 5.4616
# --- Generating with seed: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ temperature: 0.2
# the slowly ascending ranks and classes, in which,
# through fonddihd in ale  o thisthe  thit de  aihis la ie  hi an hat th tmihd  this ind e ane tht eh e a ti ththdhn he s tha  dhonath d s ath d an shihe thith  a t-on t athe  dindhththate xiasit thadit th dor tha ct   an n anis at t sond i cies aihd t st thnd athdothe i t tht tit ise atd ndhihs he aithais anhi  that t th a thod di toms thd  tharsde asit thds t d on de th dith tn dather a te in  ihdd io vdsou
# ------ temperature: 0.5
# the slowly ascending ranks and classes, in which,
# through fore ids sihatce ehdi t sind e thase a ndw tsiet ain  stio tnle he oatontdhsihti s tne sthainddi oset s dsei or thu ou ceons ani ththou he ltsn d aisiihihn  anes ro o lhsa nhsh de d  o oie noor th th o  enseneniin o tndihi alntthe tat aaai hht rr err iro forhec ir t stanldqits is ath. tio alo alhci d cs tesahs uds  th s inrtndd o a t tis o honor stens s  id arhisse nd isdot ooni thin atlh  ous t l r
# ------ temperature: 1.0
# the slowly ascending ranks and classes, in which,
# through foreral  at oarie aeaiohjeat ion d eres leeene s tl issdd  toiatst hs atisde  itlol dyteotla hdo"s sol o iuddhteihaensn alo dsi iess  aleinoonesotudtbhatii rerrsauast rlr oiiuesi netuein te h nes t tiles s  atlissath dtloihsat loonent aaotrnascndae heaha oncn uinhs  dittonsa"neetteludi lzondahaosetshetit e ialh tonelaial ntrerns diisl h dttthirsi uahashths nd tnlneshaohosilhseotsnee oloi an o s duih
# ------ temperature: 1.2
# the slowly ascending ranks and classes, in which,
# through foitri otrhthronenhbl  s tohautslelhud  hoan ahot o anos ilcr ot onlohtaand thdtshsit on tltethnt s aoh lnduliaet eenlithlode ts oeth tta tarndtthudot ie do
# n inues othtris ihh ahtisoidhs oueluld isadt tnneuun eiuirnut o horaraol1ihassihorelonttiateeoan aa  rasisonsre ludaoeisteerhe dsii thders alsuhiitness rh e ttaluunan  oe onenh s  l"s td eiashhlihneu elo nohlasloheaeit dd uh t tuinsasines oats
# epoch 57
# Epoch 1/1
# 200278/200278 [==============================] - 80s 397us/step - loss: 5.2633
# --- Generating with seed: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ temperature: 0.2
# the slowly ascending ranks and classes, in which,
# through for t athee iore it ie t ae t yo oath t tht aenao th d h s t  td re a  aaotjd andile an athe o tnon a a t ae  ente ere t t sthe at o  t  ont e an t ae the  t therlve e he he tht e at te toe   th    tne  i e t teno t ae  ie sthe d thhk anther  ath t thche aer the  th th th ne e at oe e er a the th   th  oothi  ath thehe aeez aee athe   the e    n o  there  e aq t  the he tn orl t the thae e th io an
# ------ temperature: 0.5
# the slowly ascending ranks and classes, in which,
# through forhit anare iie o r ale ane ahede at t t  tr  eon t t derel s  o at t tt e thi the aah on  ihih o ase"e the inn n th  aitne  te . thl ice se a otz ala   thele eondee h shent hehe the a nt ortslt aele th th heee ats  "he thel ti es afis e ioheihoos lis he  tolhenon  in erssethnin tneetn isii  th ino e hdats te n  e rthl aceth te themehj rtatnt et tas  alathale the t ie sonane th  thet ninae s tee on
# ------ temperature: 1.0
# the slowly ascending ranks and classes, in which,
# through fo nesh saterirtothraeeuo ieni  c e  at ittoan' atss   orteaooueandaen ta  o oeeth acrels atensto "areis aineneon e   ece el drd n thhaeal asooditohe eal ditie th sstr thintt itia anol thlottalatssn e hi ttq s  andlea oohoseu e t ehhrrn inahlhr  orrnotouluelatnhnae dah n teoltaso lderainle tsat  tsls lol en t do sithyt oe s tntse raldte lrrtsesrsniethln aunraroe hle at  sistna oeed erhths r ahiaihes
# ------ temperature: 1.2
# the slowly ascending ranks and classes, in which,
# through fola oo oen ha oilhlrdro isseseo  nd uo e aatnisroihsinela aooe lanm tth aiod  hl tlle olenotanite iaista  s inuaaitaosinastue hedahonos s srntshee theo  hr  ile essdiinonoaeo eealeatie tntnero ohrir  cealondsi tdt laddt edaula io-suderaris ninle sn t ho itt o th ieisiaaoahhor totaln siasteor hl ale  raniihdith nt inatfe  oaonldooihes ut d o  oaas o ouaao sud hhre arair as tns ren e hoshelsier sa ns
# epoch 58
# Epoch 1/1
# 200278/200278 [==============================] - 78s 392us/step - loss: 5.1521
# --- Generating with seed: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ temperature: 0.2
# the slowly ascending ranks and classes, in which,
# through foren td th t dek t the th  hm the an  co in andn      oheé an to  aot iw em   n t d  t  ont hen t tt t a   ch
# s nocnc y cde tet ind-at  hmd  t  cs  t  ch t  t cehee th t cth  e s dand tndenn chi this ce t  nd tcouc t:inent  t dathe os t c  c  oi at nes  or the ah tnc octhe t oeh c oncthern n nd  e orf o  c t it ther  iin ode a de  in th  t o th o
# t ce  he anet a io  the th thete and cths en he  an
# ------ temperature: 0.5
# the slowly ascending ranks and classes, in which,
# through foine  esncu  anrhir ehio  tln d aintdh  uatuo   cce aa i  n   hr oe e m  dhereje en  noqgesstelan ie to ene co    neno the t er o  on n sor itht s ooue den to e ah toen nel athi t  thehees oeginl ithe t    aedton se ia cd s arndt   the ante  t ae int an tl d n chete ntsir te  ande!sn t tnerddeeinaon?nc tn hurwe a ue mtbuuo ci ei ouri ae ice dee sie tsr ions in atstlel ioo n hn t e t  cs the ct  i s
# ------ temperature: 1.0
# the slowly ascending ranks and classes, in which,
# through fodenere anst ndireiteoaon atee tl su holthl iertth r saeoels o tn s dhene itera arot nas hrnonesisatloino csutu ls s s aoirreeanahas ouass ihlioehos ndoc   it acsdilo it n ua r arrsutoaths s dt  the aiiniscittrerins ornd dpeelneauluutir ilnird t intnilrtrcheitu aetienlun ndroddd chidtdnert au d iu iende osnnntld"haiontrdiitedieuss ltt shrdi hnedsh iseidnd s o nit ro incsele iodrernatnd isto th eo i
# ------ temperature: 1.2
# the slowly ascending ranks and classes, in which,
# through fooec lshciorh ith edt tsenalzt thnouesehsseti thal osla e tnrl uiheohloudias uiehieo suhirsss sareh  l  roths els  hl lnuisaa"ndatnee n cs l t dathsnosarndarh eeatoddhin ihns stho esunrrntshu  adot rreer alcddcrocattuathzenn; tboee ttuosseet dh dtt stldrntsnrio anntlsthkiatu ie oo n dhinoerh or htheiailtheneeare d tineodonhteiiou outotsunndio  oneia ndthind"ie oa i ,  iehe dumarea  hcirc ieat  ci
# epoch 59
# Epoch 1/1
# 200278/200278 [==============================] - 79s 395us/step - loss: 5.0112
# --- Generating with seed: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ temperature: 0.2
# the slowly ascending ranks and classes, in which,
# through fore  o oc thm   a thnth s heen s ate  n the ath coratheet a t a o  t to in    enshe t t  a r   s  o   o theee o t the nn tb amt on anhet  th  tnoenc ah t tha   oe it t in e wean  an t s indoet the t
# a "e e t an i thenee n th it e th a der o on o the t n  th ath an t
#   o t ie denc inen ae  in rnso  th t theeon th e at dontthe  he th the e ths in a  t t  coit i thene  de t th   thamk hne necn  ce c
# ------ temperature: 0.5
# the slowly ascending ranks and classes, in which,
# through fore  thh u asser sh iend   n se tyieyesertth mrsio hs io  n s o as th n h o soi a"eon  th    an-  ow aatran h     s nancr oni  o  a nanerpen t uereoe ne td th aaninctn t sh th  (s d ts t t di atheuo oidiua  itheee  diua  hhe on od0in eih  hi utharnt se cases anh hth shne neasixes seona ehns
# shnc s snl th e-oth r ou h  anne enon o s thir n tther  s el" on it t we a  o"noe  doionend notod heur  th  o
# ------ temperature: 1.0
# the slowly ascending ranks and classes, in which,
# through forintora
# tnoinafonh reo  stua c dh ;h u
# mo e cv nenhnue sinas ooenn6hmor sc a  on1laacydhdehhit n aes
# (andlr u tese anryhls otl  t  aoydaioi shert therfnthh aneinet to olsleh ose aeh erd thasoo nd
# ceddaiauret tidaseehhse ieeou e n t "e itanh asdolc lasortehesedhhu  uthah
#  at oe seliti en heno drdusn ihhe s tohe riniduansherao ce sudlthur rus   ondlantoihie ia t  u shk
# inbe diaish mat leral"inonno
# ------ temperature: 1.2
# the slowly ascending ranks and classes, in which,
# through foee  stceshei o shhna a dahhtleet otdnd reeenhecheelrirtasialeiniros  dis ateritued alersatntehoreloxttn c ir n i c ochinn  hi e oncemhcr"atleto
# trs ennntesqltsoloua outhh otanndo than  ho aehts a htoinlonrdit r  ncoolh trof at useu s tnoitchns c c t ed sithouinhiaosrsnetsot  lrhu rciaoairo  thhn e ern ounhro cte"nt asirbaneo itht netholh tsheenotah aehh rnt an hanesue otrehct n i chr hechtne sas

# %% [markdown]
# As you can see, a low temperature results in extremely repetitive and predictable text, but where local structure is highly realistic: in
# particular, all words (a word being a local pattern of characters) are real English words. With higher temperatures, the generated text
# becomes more interesting, surprising, even creative; it may sometimes invent completely new words that sound somewhat plausible (such as
# "eterned" or "troveration"). With a high temperature, the local structure starts breaking down and most words look like semi-random strings
# of characters. Without a doubt, here 0.5 is the most interesting temperature for text generation in this specific setup. Always experiment
# with multiple sampling strategies! A clever balance between learned structure and randomness is what makes generation interesting.
#
# Note that by training a bigger model, longer, on more data, you can achieve generated samples that will look much more coherent and
# realistic than ours. But of course, don't expect to ever generate any meaningful text, other than by random chance: all we are doing is
# sampling data from a statistical model of which characters come after which characters. Language is a communication channel, and there is
# a distinction between what communications are about, and the statistical structure of the messages in which communications are encoded. To
# evidence this distinction, here is a thought experiment: what if human language did a better job at compressing communications, much like
# our computers do with most of our digital communications? Then language would be no less meaningful, yet it would lack any intrinsic
# statistical structure, thus making it impossible to learn a language model like we just did.
#
#
# ## Take aways
#
# * We can generate discrete sequence data by training a model to predict the next tokens(s) given previous tokens.
# * In the case of text, such a model is called a "language model" and could be based on either words or characters.
# * Sampling the next token requires balance between adhering to what the model judges likely, and introducing randomness.
# * One way to handle this is the notion of _softmax temperature_. Always experiment with different temperatures to find the "right" one.
